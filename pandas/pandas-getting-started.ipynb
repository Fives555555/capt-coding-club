# %% [markdown]
# # Pandas
#
#
#
# Pandas is a Python library used for working with datasets. It does that by helping us make sense of DataFrames, which are a form of two-dimensional structured data, like a table with columns and rows. But before we can do anything else, we need to start with data in a CSV file.

# %% [markdown]
# # Importing Data

# %% [markdown]
# ## CSV Files
#
#
#
# CSV stands for Comma Separated Values, and it's a file type that allows data to be saved in a table. Data presented in a table is called structured data, because it adheres to the idea that there is a meaningful relationship between the columns and rows.

# %%
import pandas as pd 

df = pd.read_csv('data/iris.csv')

df.head()
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %%
df.columns
# Out:
# Index(['5.1', '3.5', '1.4', '0.2', 'Iris-setosa'], dtype='object')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## Dictionaries

# %% [markdown]
# You can create a DataFrame from a Python dictionary using from_dict function.

# %%
import pandas as pd

data = {"col_1": [3, 2, 1, 0], "col_2": ["a", "b", "c", "d"]}
pd.DataFrame.from_dict(data)
# Out:
#    col_1 col_2
# 0      3     a
# 1      2     b
# 2      1     c
# 3      0     d

# %% [markdown]
# By default, DataFrame will be created using keys as columns. Note the length of the values should be equal for each key for the code to work. We can also let keys to be index instead of the columns:

# %%
pd.DataFrame.from_dict(data, orient="index")
# Out:
#        0  1  2  3
# col_1  3  2  1  0
# col_2  a  b  c  d

# %% [markdown]
# We can also specify column names:

# %%
pd.DataFrame.from_dict(data, orient="index", columns=["A", "B", "C", "D"])
# Out:
#        A  B  C  D
# col_1  3  2  1  0
# col_2  a  b  c  d

# %% [markdown]
# ## JSON Files

# %% [markdown]
# JSON is short for JavaScript Object Notation. It is another widely used data format to store and transfer the data. It is light-weight and very human readable. In Python, we can use the json library to read JSON files. Here is an example of a JSON string.

# %%
info = """{
    "firstName": "Jane",
    "lastName": "Doe",
    "hobby": "running",
    "age": 35
}"""
print(info)
# Out:
# {
#     "firstName": "Jane",
#     "lastName": "Doe",
#     "hobby": "running",
#     "age": 35
# }

# %% [markdown]
# Use json library to load the json string into a Python dictionary:

# %%
import json

data = json.loads(info)
data
# Out:
# {'firstName': 'Jane', 'lastName': 'Doe', 'hobby': 'running', 'age': 35}

# %% [markdown]
# We can load a json string or file into a dictionary because they are organized in the same way: key-value pairs.

# %%
data["firstName"]
# Out:
# 'Jane'

# %% [markdown]
# A dictionary may not be as convenient as a DataFrame in terms of data manipulation and cleaning. But once we've turned our json string into a dictionary, we can transform it into a DataFrame using the from_dict method.

# %%
df = pd.DataFrame.from_dict(data, orient="index", columns=["subject 1"])
df
# Out:
#           subject 1
# firstName      Jane
# lastName        Doe
# hobby       running
# age              35

# %% [markdown]
# # Loading Compressed file in Python
# In the big data era, it is very likely that we'll need to read data from compressed files.

# %%
import pandas as pd 

df = pd.read_csv('data/public_company_bankruptcy_cases_2011.zip', compression='zip')

# %%
df
# Out:
#    DISTRICT STATE                            COMPANY NAME ASSETS (MILLIONS)  \
# 0         D    NV         Ad Systems Communications, Inc.               405
# 1         D    NV                          Alphatrade.com               686
# 2        SD    NY                   AMBAC Financial Group               395
# 3         D    DE         Ambassdors International , Inc.             86.44
# 4         D    NV  American Pacific Financial Corporation             19.18
# ..      ...   ...                                     ...               ...
# 62      NaN   NaN                                     NaN               NaN
# 63      NaN   NaN                                     NaN               NaN
# 64      NaN   NaN                                     NaN               NaN
# 65      NaN   NaN                                     NaN               NaN
# 66      NaN   NaN                                     NaN               NaN
#
#    LIABILITIES (MILLIONS)
# 0                       4
# 1                       4
# 2                   1,683
# 3                   87.32
# 4                  161.08
# ..                    ...
# 62                    NaN
# 63                    NaN
# 64                    NaN
# 65                    NaN
# 66                    NaN
#
# [67 rows x 5 columns]

# %%
df.columns
# Out:
# Index(['DISTRICT', 'STATE', 'COMPANY NAME', 'ASSETS (MILLIONS)',
#        'LIABILITIES (MILLIONS)'],
#       dtype='object')

# %%
df.head()
# Out:
#   DISTRICT STATE                            COMPANY NAME ASSETS (MILLIONS)  \
# 0        D    NV         Ad Systems Communications, Inc.               405
# 1        D    NV                          Alphatrade.com               686
# 2       SD    NY                   AMBAC Financial Group               395
# 3        D    DE         Ambassdors International , Inc.             86.44
# 4        D    NV  American Pacific Financial Corporation             19.18
#
#   LIABILITIES (MILLIONS)
# 0                      4
# 1                      4
# 2                  1,683
# 3                  87.32
# 4                 161.08

# %% [markdown]
# ## Pickle Files

# %% [markdown]
# The pickle module in Python is used for serializing and deserializing Python objects.
#
# Serialization (also called pickling) is the process of converting a Python object in memory into a byte stream so that it can be stored on disk or transmitted over a network.
#
# Deserialization (or unpickling) is the reverse operation — converting a byte stream back into a Python object in memory.
#
# According to the official documentation, the following types of objects can be pickled:
#
# - None
# - Boolean values
# - Numeric types: integers, floats, complex numbers
# - Strings (both normal and Unicode)
# - Collections such as tuples, lists, sets, and dictionaries (provided their contents are picklable)
# - Functions defined at the top level of a module
# - Built-in functions defined at the top level of a module
# - Classes defined at the top level of a module

# %%
# Define a dictionary to store clothing items and their attributes (color, size)
clothes = {
    "shirt": ["red", "M"],
    "pant": ["yellow", "L"],
    "jacket": ["black", "L"]
}

# Display the dictionary
clothes
# Out:
# {'shirt': ['red', 'M'], 'pant': ['yellow', 'L'], 'jacket': ['black', 'L']}

# %%
import pickle

pickle.dump(clothes, open("./data/clothes.pkl", "wb"))

# %% [markdown]
# Now in the data folder, there will be a file named clothes.pkl. We can read the pickled file using the following code:

# %%
with open("./data/clothes.pkl", "rb") as f:
    unpickled = pickle.load(f)

# %%
unpickled
# Out:
# {'shirt': ['red', 'M'], 'pant': ['yellow', 'L'], 'jacket': ['black', 'L']}

# %% [markdown]
# Note first we are using wb inside the open function because we are creating this file, while deserializing the file, we are using rb to read the file

# %% [markdown]
# # Working with DataFrames
#
#
#
# The first thing we need to do is import pandas; we'll use pd as an alias when we include it in our code.
#
#
# Pandas is just a library; to get anything done, we need a dataset too. We'll use the read_csv method to create a DataFrame from a CSV file.

# %%
import pandas as pd


df = pd.read_csv("data/iris.csv",names=['Sepal_Length','Sepal_Width','Petal_Length','Petal_Width','Species'])
df.head()
# Out:
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width      Species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# # Working with DataFrame Indices

# %% [markdown]
# We can call the index column through .index:

# %%
df.index[:5]
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %% [markdown]
# Use the set_index method, we can set the column department as the index instead. Note index column cannot have duplicate rows, like here we cannot set property_type as the index column.

# %%
df.set_index("Sepal_Length", inplace=True)
df.head()
# Out:
#               Sepal_Width  Petal_Length  Petal_Width      Species
# Sepal_Length
# 5.1                   3.5           1.4          0.2  Iris-setosa
# 4.9                   3.0           1.4          0.2  Iris-setosa
# 4.7                   3.2           1.3          0.2  Iris-setosa
# 4.6                   3.1           1.5          0.2  Iris-setosa
# 5.0                   3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# Now you can see the index column has changed:

# %%
df['Sepal_Length']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/AI_bootcamp/lib/python3.13/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Sepal_Length'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 df['Sepal_Length']
#
# File ~/miniconda3/envs/AI_bootcamp/lib/python3.13/site-packages/pandas/core/frame.py:4107, in DataFrame.__getitem__(self, key)
#    4105 if self.columns.nlevels > 1:
#    4106     return self._getitem_multilevel(key)
# -> 4107 indexer = self.columns.get_loc(key)
#    4108 if is_integer(indexer):
#    4109     indexer = [indexer]
#
# File ~/miniconda3/envs/AI_bootcamp/lib/python3.13/site-packages/pandas/core/indexes/base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'Sepal_Length'

# %% [markdown]
# Using the reset_index() function, we can reset index back to default integer counts, and department will become a column again.

# %%
df.reset_index(inplace=True)
df.head()
# Out:
#    index  Sepal_Length  Sepal_Width  Petal_Length  Petal_Width      Species
# 0      0           5.1          3.5           1.4          0.2  Iris-setosa
# 1      1           4.9          3.0           1.4          0.2  Iris-setosa
# 2      2           4.7          3.2           1.3          0.2  Iris-setosa
# 3      3           4.6          3.1           1.5          0.2  Iris-setosa
# 4      4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# # Inspecting DataFrames
#
# After creating a DataFrame, it is essential to inspect its contents to understand its structure and the type of data it holds.
# Pandas provides several convenient methods for this purpose. In this section, we will focus on three commonly used ones: shape, info(), and head().
#
# To examine the dimensionality of a DataFrame (i.e., the number of rows and columns), we can use the df.shape attribute.
# Here’s an example:

# %%
df.shape
# Out:
# (150, 5)

# %% [markdown]
# The shape output tells us that the iris DataFrame has 150 rows and 5 columns.

# %% [markdown]
# If we're trying to get a general idea of what the DataFrame contained, we can use the info method. The code looks like this:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Sepal_Length  150 non-null    float64
#  1   Sepal_Width   150 non-null    float64
#  2   Petal_Length  150 non-null    float64
#  3   Petal_Width   150 non-null    float64
#  4   Species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# The info() output provides a concise summary of the DataFrame. It displays the number of columns, their names, the data type of each column, and the count of non-null (non-missing) entries. This information is particularly useful for quickly assessing the structure and completeness of your dataset.

# %% [markdown]
# If we want to display all the rows in our DataFrame, we can use the print() function. However, this approach prints the entire dataset, which can be impractical for large DataFrames. While it may not pose an issue for small datasets, printing large ones can significantly slow down your workflow or overwhelm your console output.
#
# A better approach is to preview only the first few rows using the head() method. By default, df.head() returns the first five rows of the DataFrame:

# %%
df.head()
# Out:
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width      Species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# By default, head returns the first five rows of data, but you can specify as many rows as you like. Here's what the code looks like for just the first two rows:

# %%
print(df.head(2))
# Out:
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width      Species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa

# %% [markdown]
# # Sorting

# %% [markdown]
# We can sort the whole DataFrame by values of a column.

# %%
df.sort_values("Sepal_Width").head()
# Out:
#      Sepal_Length  Sepal_Width  Petal_Length  Petal_Width          Species
# 60            5.0          2.0           3.5          1.0  Iris-versicolor
# 62            6.0          2.2           4.0          1.0  Iris-versicolor
# 119           6.0          2.2           5.0          1.5   Iris-virginica
# 68            6.2          2.2           4.5          1.5  Iris-versicolor
# 87            6.3          2.3           4.4          1.3  Iris-versicolor

# %% [markdown]
# We can also sort the DataFrame by it's index.

# %%
(df
 .set_index("Sepal_Length")
 .sort_index()
 .head()
 )
# Out:
#               Sepal_Width  Petal_Length  Petal_Width      Species
# Sepal_Length
# 4.3                   3.0           1.1          0.1  Iris-setosa
# 4.4                   2.9           1.4          0.2  Iris-setosa
# 4.4                   3.2           1.3          0.2  Iris-setosa
# 4.4                   3.0           1.3          0.2  Iris-setosa
# 4.5                   2.3           1.3          0.3  Iris-setosa

# %% [markdown]
# # Working with Columns

# %% [markdown]
# ## Adding Columns

# %%
df["Sepal_Length2"] = df["Sepal_Length"]**2
df.head()
# Out:
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width      Species  \
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
#
#    Sepal_Length2
# 0          26.01
# 1          24.01
# 2          22.09
# 3          21.16
# 4          25.00

# %% [markdown]
# ## Dropping Columns

# %%
df = df.drop("Sepal_Length2", axis="columns")
df.head()
# Out:
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width      Species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# Note that we specified that we wanted to drop a column by setting the axis argument to "columns". We can drop rows from the dataset if we change the axis argument to "index". If we wanted to drop row 2 from the df2 data, the code would look like this:

# %%
df2 = df.drop(1, axis="index")
df2.head()
# Out:
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width      Species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# 5           5.4          3.9           1.7          0.4  Iris-setosa

# %% [markdown]
# ## Adding Row

# %%
# Create a new row as a dictionary
new_row = {
    "Sepal_Length": 5.1,
    "Sepal_Width": 3.8,
    "Petal_Length": 1.5,
    "Petal_Width": 0.3,
    "Species": 'Iris-virginica'
}

# Add the new row using loc
df.loc[len(df)] = new_row

# Verify the addition
df.tail()
# Out:
#      Sepal_Length  Sepal_Width  Petal_Length  Petal_Width         Species
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
# 150           5.1          3.8           1.5          0.3  Iris-virginica

# %% [markdown]
# ## Dropping NaN
#
#
#
# Including rows with empty cells can radically skew the results of our analysis, so we often drop them from the dataset.

# %%
import numpy as np
# Create a new row as a dictionary
new_row = {
    "Sepal_Length": np.nan,
    "Sepal_Width": np.nan,
    "Petal_Length": 3.2,
    "Petal_Width": np.nan,
    "Species": 'Iris-virginica'
}

# Add the new row using loc
df.loc[len(df)] = new_row

# Verify the addition
df.tail()
# Out:
#      Sepal_Length  Sepal_Width  Petal_Length  Petal_Width         Species
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
# 150           5.1          3.8           1.5          0.3  Iris-virginica
# 151           NaN          NaN           3.2          NaN  Iris-virginica

# %%
print("df shape before dropping rows", df.shape)
df.dropna(inplace=True)
print("df shape after dropping rows", df.shape)
df.tail()
# Out:
# df shape before dropping rows (152, 5)
# df shape after dropping rows (151, 5)
#      Sepal_Length  Sepal_Width  Petal_Length  Petal_Width         Species
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
# 150           5.1          3.8           1.5          0.3  Iris-virginica

# %% [markdown]
# ## Splitting Strings
#
#
#
# It might be useful to split strings into their constituent parts, and create new columns to contain them. To do this, we’ll use the .str.split method, and include the character we want to use as the place where the data splits apart. In the colombia-real-estate-3 dataset, we might be interested breaking the "lat-lon" column into a "lat" column and a "lon" column. We’ll split it at “,” with code that looks like this:

# %%
df[["Flower", "Type"]] = df["Species"].str.split("-", expand=True)
df
# Out:
#      Sepal_Length  Sepal_Width  Petal_Length  Petal_Width         Species  \
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
# 150           5.1          3.8           1.5          0.3  Iris-virginica
#
#     Flower       Type
# 0     Iris     setosa
# 1     Iris     setosa
# 2     Iris     setosa
# 3     Iris     setosa
# 4     Iris     setosa
# ..     ...        ...
# 146   Iris  virginica
# 147   Iris  virginica
# 148   Iris  virginica
# 149   Iris  virginica
# 150   Iris  virginica
#
# [151 rows x 7 columns]

# %% [markdown]
# ## Recasting Data

# %%
print(df.info())
newdf = df.astype("str")
print(newdf.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 151 entries, 0 to 150
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Sepal_Length  151 non-null    float64
#  1   Sepal_Width   151 non-null    float64
#  2   Petal_Length  151 non-null    float64
#  3   Petal_Width   151 non-null    float64
#  4   Species       151 non-null    object
#  5   Flower        151 non-null    object
#  6   Type          151 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 9.4+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Index: 151 entries, 0 to 150
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Sepal_Length  151 non-null    object
#  1   Sepal_Width   151 non-null    object
#  2   Petal_Length  151 non-null    object
#  3   Petal_Width   151 non-null    object
#  4   Species       151 non-null    object
#  5   Flower        151 non-null    object
#  6   Type          151 non-null    object
# dtypes: object(7)
# memory usage: 9.4+ KB
# None

# %%
df['Petal_Length2'] = (df.Petal_Length**2).astype(int)
df.head()
# Out:
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width      Species Flower  \
# 0           5.1          3.5           1.4          0.2  Iris-setosa   Iris
# 1           4.9          3.0           1.4          0.2  Iris-setosa   Iris
# 2           4.7          3.2           1.3          0.2  Iris-setosa   Iris
# 3           4.6          3.1           1.5          0.2  Iris-setosa   Iris
# 4           5.0          3.6           1.4          0.2  Iris-setosa   Iris
#
#      Type  Petal_Length2
# 0  setosa              1
# 1  setosa              1
# 2  setosa              1
# 3  setosa              2
# 4  setosa              1

# %% [markdown]
# ## Access a substring in a Series

# %%
df["Species"].str[0:5:2]
# Out:
# 0      Ii-
# 1      Ii-
# 2      Ii-
# 3      Ii-
# 4      Ii-
#       ...
# 146    Ii-
# 147    Ii-
# 148    Ii-
# 149    Ii-
# 150    Ii-
# Name: Species, Length: 151, dtype: object

# %% [markdown]
# ## Replacing String Characters

# %%
df["Flower"] = df["Flower"].str.replace("ris", "RIS")
df.head()
# Out:
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width      Species Flower  \
# 0           5.1          3.5           1.4          0.2  Iris-setosa   IRIS
# 1           4.9          3.0           1.4          0.2  Iris-setosa   IRIS
# 2           4.7          3.2           1.3          0.2  Iris-setosa   IRIS
# 3           4.6          3.1           1.5          0.2  Iris-setosa   IRIS
# 4           5.0          3.6           1.4          0.2  Iris-setosa   IRIS
#
#      Type  Petal_Length2
# 0  setosa              1
# 1  setosa              1
# 2  setosa              1
# 3  setosa              2
# 4  setosa              1

# %% [markdown]
# ### Rename a column

# %%
df.rename(columns={"Type": "Kind"})
# Out:
#      Sepal_Length  Sepal_Width  Petal_Length  Petal_Width         Species  \
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
# 150           5.1          3.8           1.5          0.3  Iris-virginica
#
#     Flower       Kind  Petal_Length2
# 0     IRIS     setosa              1
# 1     IRIS     setosa              1
# 2     IRIS     setosa              1
# 3     IRIS     setosa              2
# 4     IRIS     setosa              1
# ..     ...        ...            ...
# 146   IRIS  virginica             25
# 147   IRIS  virginica             27
# 148   IRIS  virginica             29
# 149   IRIS  virginica             26
# 150   IRIS  virginica              2
#
# [151 rows x 8 columns]

# %% [markdown]
# ### Determine the unique values in a column

# %%
df["Species"].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %% [markdown]
# ## Replacing Column Values

# %% [markdown]
# If you want to replace a columns' values, simply use the .replace() function:

# %%
df["Petal_Length2"].replace(1, 10)
# Out:
# 0      10
# 1      10
# 2      10
# 3       2
# 4      10
#        ..
# 146    25
# 147    27
# 148    29
# 149    26
# 150     2
# Name: Petal_Length2, Length: 151, dtype: int64

# %%
replace_value = {10: 1, 2: 20}

df["Petal_Length2"].replace(replace_value)
# Out:
# 0       1
# 1       1
# 2       1
# 3      20
# 4       1
#        ..
# 146    25
# 147    27
# 148    29
# 149    26
# 150    20
# Name: Petal_Length2, Length: 151, dtype: int64

# %% [markdown]
# # Concatenating

# %% [markdown]
# ## Concatenating DataFrames
#
#
#
# If we want to combine two DataFrames, we need to import Pandas and read in our data.

# %%
df1 = pd.read_csv("data/iris.csv",names=['Sepal_Length','Sepal_Width','Petal_Length','Petal_Width','Species'])
df2 = pd.read_csv("data/iris.csv",names=['Sepal_Length','Sepal_Width','Petal_Length','Petal_Width','Species'])
print("df1 shape:", df1.shape)
print("df2 shape:", df2.shape)
# Out:
# df1 shape: (150, 5)
# df2 shape: (150, 5)

# %%
concat_df = pd.concat([df1, df2])
print("concat_df shape:", concat_df.shape)
concat_df.head()
# Out:
# concat_df shape: (300, 5)
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width      Species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# ## Concatenating Series
#
#
#
# We can also concatenate a Series using a similar set of commands. First, let's take two Series from the df1 and df2 respectively.

# %%
sr1 = df1["Petal_Length"]
sr2 = df2["Petal_Length"]
print("len sr1:", len(sr1)),
print(sr1.head())
print()
print("len sr2:", len(sr2)),
print(sr2.head())
# Out:
# len sr1: 150
# 0    1.4
# 1    1.4
# 2    1.3
# 3    1.5
# 4    1.4
# Name: Petal_Length, dtype: float64
#
# len sr2: 150
# 0    1.4
# 1    1.4
# 2    1.3
# 3    1.5
# 4    1.4
# Name: Petal_Length, dtype: float64

# %%
concat_sr = pd.concat([sr1, sr2])
print("len concat_sr:", len(concat_sr)),
print(concat_sr.head())
# Out:
# len concat_sr: 300
# 0    1.4
# 1    1.4
# 2    1.3
# 3    1.5
# 4    1.4
# Name: Petal_Length, dtype: float64

# %%
df
# Out:
#      Sepal_Length  Sepal_Width  Petal_Length  Petal_Width         Species  \
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
# 150           5.1          3.8           1.5          0.3  Iris-virginica
#
#     Flower       Type  Petal_Length2
# 0     IRIS     setosa              1
# 1     IRIS     setosa              1
# 2     IRIS     setosa              1
# 3     IRIS     setosa              2
# 4     IRIS     setosa              1
# ..     ...        ...            ...
# 146   IRIS  virginica             25
# 147   IRIS  virginica             27
# 148   IRIS  virginica             29
# 149   IRIS  virginica             26
# 150   IRIS  virginica              2
#
# [151 rows x 8 columns]

# %% [markdown]
# # Saving a DataFrame as a CSV

# %%
df.to_csv("data/iris_mod.csv",index=False)
